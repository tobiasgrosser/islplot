# %%
# Load islpy and islplot
from islpy import *
from islplot.plotter import *

# Reload plotter each time "Run All" is executed.
# This allows modifications in islplot to take effect without having to restart
# the kernel
import islplot.plotter
import imp
imp.reload(islplot.plotter)
# Out:
# <module 'islplot.plotter' from '/home/grosser/Projects/islplot/islplot/plotter.py'>

# %%
plot_set_points(Set("{S[x,y]: 0 <= x <= 8 and -7 <= y <= 5}"),
                marker=".", color="gray", size=3)

plot_set_points(Set("{S[x,y]: 0 < x < 8 and 0 < y + x < 5}"),
                marker="o")

plot_set_points(Set("{S[x,y]: 4 < x < 8 and 0 < y < 5}"),
                marker="s", color="red")

plot_set_points(Set("{S[x,y]: 0 < x and y > -6 and y + x < 0}"),
                marker="D", color="blue")

# %%
s1 = Set("{S[i,j]: 0 < i = j < 10}")
plot_set_points(s1, size=20, color="red")

# %%
m1 = Map("{S[2,8] -> [i,j]: 1 < i = j < 9}")
s3 = Set("{S[2,8]}")
plot_set_points(s1)
plot_set_points(s3)
plot_map(m1)

# %%
bs1 = BasicSet("{S[i,j]: 0 < i, j < 10}")
plot_set_points(bs1)
bs0 = BasicSet("{S[i,j]: 1 < 2i < j + i < 9}")
plot_bset_shape(bs0, plot_vert=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-e4fdc8d358e9> in <module>()
#       2 plot_set_points(bs1)
#       3 bs0 = BasicSet("{S[i,j]: 1 < 2i < j + i < 9}")
# ----> 4 plot_bset_shape(bs0, plot_vert=True)
#
# /home/grosser/Projects/islplot/islplot/plotter.py in plot_bset_shape(bset_data, show_vertices, *args, **kwargs)
#     174     codes, verts = zip(*pathdata)
#     175     path = Path(verts, codes)
# --> 176     patch = PathPatch(path, **kwargs)
#     177     _plt.gca().add_patch(patch)
#     178
#
# /usr/lib/python3/dist-packages/matplotlib/patches.py in __init__(self, path, **kwargs)
#     779
#     780         """
# --> 781         Patch.__init__(self, **kwargs)
#     782         self._path = path
#     783
#
# ...

# %%
s4 = Set("{S[i,j]: 1 <= i,j <= 3 or 5 <= i,j <= 7}")
plot_set_shapes(s4)
